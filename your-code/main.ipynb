# %% [markdown]
# ## Words

# %%
words = ['play', 'filling', 'bar', 'theatre', 'easygoing', 'date', 'lead', 'that', 'story',  'island']

# %% [markdown]
# **Print every word in upper case**

# %%
# your code here
for word in words:
    print(word.upper())
# Out:
# PLAY
# FILLING
# BAR
# THEATRE
# EASYGOING
# DATE
# LEAD
# THAT
# STORY
# ISLAND

# %% [markdown]
# **Create a new list containing only words with 5 or more letters**

# %%
# your code here
for word in words:
    if len(word) >= 5:
        print(word)
# Out:
# filling
# theatre
# easygoing
# story
# island

# %% [markdown]
# **Print the first word starting with "t"**

# %%
# your code here
for word in words:
    if word[0] == 't':
        print(word)
        break
# Out:
# theatre

# %% [markdown]
# ## Numbers

# %% [markdown]
# **Create a list containing the square of every number from 1 to 10**

# %%
# your code here
new_list = []

for i in range(1, 11):
    new_list.append(i**2)

new_list
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %% [markdown]
# **Print a list containing the square of every odd number from 1 to 10**

# %%
# your code here

odd_numbers = []

for i in range(1, 10, 2):
    if i % 2 != 0:
        odd_numbers.append(i**2)

odd_numbers
# Out:
# [1, 9, 25, 49, 81]

# %% [markdown]
# **Create a list with the squares of all multiples of 8 below 1000**

# %%
# your code here

squares_list = []

for i in range(1, 1000):
    if i % 8 == 0:
        squares_list.append(i**2) 

squares_list
# Out:
# [64,
#  256,
#  576,
#  1024,
#  1600,
#  2304,
#  3136,
#  4096,
#  5184,
#  6400,
#  7744,
#  9216,
#  10816,
#  12544,
#  14400,
#  16384,
#  18496,
#  20736,
#  23104,
#  25600,
#  28224,
#  30976,
#  33856,
#  36864,
#  40000,
#  43264,
#  46656,
#  50176,
#  53824,
#  57600,
#  61504,
#  65536,
#  69696,
#  73984,
#  78400,
#  82944,
#  87616,
#  92416,
#  97344,
#  102400,
#  107584,
#  112896,
#  118336,
#  123904,
#  129600,
#  135424,
#  141376,
#  147456,
#  153664,
#  160000,
#  166464,
#  173056,
#  179776,
#  186624,
#  193600,
#  200704,
#  207936,
#  215296,
#  222784,
#  230400,
#  238144,
#  246016,
#  254016,
#  262144,
#  270400,
#  278784,
#  287296,
#  295936,
#  304704,
#  313600,
#  322624,
#  331776,
#  341056,
#  350464,
#  360000,
#  369664,
#  379456,
#  389376,
#  399424,
#  409600,
#  419904,
#  430336,
#  440896,
#  451584,
#  462400,
#  473344,
#  484416,
#  495616,
#  506944,
#  518400,
#  529984,
#  541696,
#  553536,
#  565504,
#  577600,
# ...

# %% [markdown]
# ## People

# %%
people = [
    {
        "name": "Juan",
        "age": 34,
        "n_kids": 2
    },
    {
        "name": "Pepe",
        "age": 27,
        "n_kids": 0
    },
    {
        "name": "Sonia",
        "age": 41,
        "n_kids": 1
    },
    {
        "name": "Lucía",
        "age": 22,
        "n_kids": 2
    },
    {
        "name": "Leo",
        "age": 55,
        "n_kids": 5
    }
]

# %% [markdown]
# **How many people are there?**

# %%
# your code here

print ("People count: ",  len(people))
# Out:
# People count:  5

# %% [markdown]
# **How many people have kids**?

# %%
# your code here

count = 0
for i in people:
    if i["n_kids"] > 0:
       count += 1
print("People with kids: ", count)
# Out:
# People with kids:  4

# %% [markdown]
# **How many kids do they have in total?**

# %%
# your code here
kids_count = 0
for i in people:
    kids_count += i["n_kids"] 
print("Total number of kids: ", kids_count)
# Out:
# Total number of kids:  10

# %% [markdown]
# **In a year's time, names ending with "a" will have an extra kid. Create a list of dictionaries with people's info in a year's time**

# %%
# your code here

people_with_kids = []

for i in people:
    index = len(i["name"])
    if 'a' == i["name"][index-1]:
        people_with_kids.append({i["name"]: i["n_kids"]+1})
    else:
        people_with_kids.append({i["name"]: i["n_kids"]})

people_with_kids
# Out:
# [{'Juan': 2}, {'Pepe': 0}, {'Sonia': 2}, {'Lucía': 3}, {'Leo': 5}]
